# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import pandas as pd
import json
import itertools

from pathlib import Path

# %% [markdown]
# ### Helper functions

# %%
def find_label(target, scale_factor, params):
    template_path = params['template_path']

    template = cv.imread(template_path, 0)
    template = cv.resize(template, (0, 0), fx=scale_factor[1], fy=scale_factor[0])

    method = cv.TM_CCOEFF_NORMED

    x_slice = params['template_area']['x_slice']
    y_slice = params['template_area']['y_slice']

    res = cv.matchTemplate(target[y_slice, x_slice], template, method)
    min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)

    # Determine the bottom-left corner of the matched region
    if method in [cv.TM_SQDIFF, cv.TM_SQDIFF_NORMED]:
        origin = min_loc
    else:
        origin = max_loc

    #  Correct for the slice
    origin = (origin[0] + x_slice.start,
              origin[1] + y_slice.start)
    return origin

# %%
def image_angle_from_horizontal(vector):
    """Calculates the angle of a 2D vector from the horizontal (x-axis) in degrees."""
    vector = np.array(vector)

    if len(vector) != 2:
        raise ValueError("Vector must be 2D.")

    x, y = vector[0], vector[1]
    angle_radians = np.arctan2(y, x)
    angle_degrees = np.degrees(angle_radians)

    return angle_degrees

# %%
def angle_between_vectors(vector1, vector2):
    """Calculates the angle between two vectors in degrees."""
    vector1 = np.array(vector1)
    vector2 = np.array(vector2)

    dot_product = np.dot(vector1, vector2)
    magnitude1 = np.linalg.norm(vector1)
    magnitude2 = np.linalg.norm(vector2)

    if magnitude1 == 0 or magnitude2 == 0:
        # return not a number if a vector has zero magnitude.
        return float('nan')

    cosine_angle = dot_product / (magnitude1 * magnitude2)
    # clip to avoid domain errors.
    angle_radians = np.arccos(np.clip(cosine_angle, -1.0, 1.0))
    angle_degrees = np.degrees(angle_radians)

    return angle_degrees

# %%
def translate_vector(origin, vector):
    """Sets the origin of a vector to a new location."""
    vector = np.array(vector)
    origin = np.array(origin)

    return vector - origin

# %%
def scale_vector(vector, scale):
    """Scales a vector by a scalar value."""
    vector = np.array(vector)

    return vector * scale

# %%
def process_config_files(image_feature_path,
                         user_feature_list_path,
                         chip_map_path):

    image_feature_details = None
    feature_dict = None
    chip_map = None

    try:
        image_feature_details = pd.read_csv(image_feature_path)
    except FileNotFoundError:
        print(f'Error: File not found at {image_feature_path}')

    # Where the labels are according to the user (on the 'real' chip)
    try:
        with open(user_feature_list_path, 'r') as file:
            feature_dict = json.load(file)
    except FileNotFoundError:
        print(f'Error: File not found at {user_feature_list_path}')
    except json.JSONDecodeError:
        print(f'Error: Invalid JSON format in {user_feature_list_path}')

    # Where the labels are according to the chip GDSII file
    try:
        with open(chip_map_path, 'r') as file:
            chip_map = json.load(file)
    except FileNotFoundError:
        print(f'Error: File not found at {chip_map_path}')
    except json.JSONDecodeError:
        print(f'Error: Invalid JSON format in {chip_map_path}')

    # Filter chip map to only include the chip type we are interested in
    for c in chip_map["chip"]:
        if c["chip_type"] == feature_dict["chip_type"]:
            chip_map = c
            break

    return image_feature_details, feature_dict, chip_map

# %%
def find_all_labels(target, image_data, feature_list_path, image_feature_path, 
                    chip_map_path, template_path, scale_factor, PLOT=False):

    image_feature_details, feature_dict, chip_map = process_config_files(
        image_feature_path, feature_list_path, chip_map_path)

    # Extract from chip map only the features we are interested in
    if chip_map["auto_locate_grating"]:
        chip_features = feature_dict.get("features", None)
        if not chip_features:
            raise ValueError('[ERROR] No features found in "FeatureLocation.json"')

    feature_labels = [f["label"].lower() for f in chip_features]
    chip_labels = [l for l in chip_map["labels"] if l["label"].lower() in feature_labels]

    # Update chip features with template path and area to search for the feature
    for idx, f in enumerate(chip_features):
        chip_features[idx]["template_path"] = Path(template_path, f'{f['label']}.png')
        if image_feature_details is not None:
            chip_features[idx]["template_area"] = {
                "x_slice": slice(f['feature_location'][0] - 100, f['feature_location'][0] + 100),
                "y_slice": slice(f['feature_location'][1] - 100, f['feature_location'][1] + 100),
            }
        else:
            mask = image_feature_details['Label'] == f['label']
            last_row = image_feature_details[mask].iloc[-1]
            chip_features[idx]["template_area"] = {
                "x_slice": slice(last_row['x'] - 100, last_row['x'] + 100),
                "y_slice": slice(last_row['y'] - 100, last_row['y'] + 100),
            }
    # print(f'{chip_labels=}')
    # print(f'{chip_features=}')

    if PLOT:
        im_color = cv.cvtColor(cv.equalizeHist(np.fliplr(target)), cv.COLOR_GRAY2BGR)

    if image_feature_details is None:
        image_feature_details = pd.DataFrame(columns=['Image', 'Label', 'x', 'y', 'Timestamp'])
    locs = []
    image_name = image_data.file_path
    timestamp = image_data.time_stamp
    for f in chip_features:
        loc = find_label(target, scale_factor, f)
        new_data = {
            'Image': image_name,
            'Label': f["label"],
            'x': loc[0],
            'y': loc[1],
            'Timestamp': timestamp}
        new_row = pd.DataFrame([new_data])
        image_feature_details = pd.concat([image_feature_details, new_row],
                                          ignore_index=True)
        locs.append(loc)
        if PLOT:
            x, y = loc
            cv.rectangle(im_color, (x, y+5), (x+5, y), (255, 0, 0), 2)

    # Calculate the distance between all combinations of chip map and chip feature labels
    loc_combinations = itertools.combinations(range(len(chip_labels)), 2)
    dist_chip_map = []
    dist_chip_feature = []
    for a, b in loc_combinations:
        dist_chip_map.append(translate_vector(chip_labels[a]["label_origin"], chip_labels[b]["label_origin"]))
        dist_chip_feature.append(translate_vector(locs[a], locs[b]))
    # print(f'{dist_chip_map=}')
    # print(f'{dist_chip_feature=}')

    # Cacluate average scaling factor using all combinations of chip map and chip feature distances
    scale_factor = np.round(np.linalg.norm(dist_chip_feature) / np.linalg.norm(dist_chip_map), 4)
    # print(f'Updated scale factor = {scale_factor}')

    # Calculate the angle between the chip map and chip feature labels separately
    chip_map_angle = image_angle_from_horizontal(translate_vector(chip_labels[0]["label_origin"], chip_labels[1]["label_origin"]))
    chip_feature_angle = image_angle_from_horizontal(translate_vector(locs[0], locs[1]))
    # print(f'{chip_map_angle=}')
    # print(f'{chip_feature_angle=}')

    # Calculate the angle of the image compared to the chip map
    # image can then be rotated by this angle to align with the chip map
    image_angle = np.round(chip_map_angle-chip_feature_angle, 0)
    # print(f'Image angle = {image_angle}')

    if PLOT:
        fig, ax = plt.subplots(1, 1, figsize=(10, 10))
        ax.imshow(im_color)
        ax.invert_yaxis()
        plt.show()

    return scale_factor, image_angle, image_feature_details

# %%
def generate_ROI_file(image_feature_path,
                      user_feature_list_path,
                      chip_map_path,
                      ROI_path,
                      target_shape,
                      scale_factor,
                      image_angle):
    image_feature_details, _, chip_map = process_config_files(
            image_feature_path, user_feature_list_path, chip_map_path)

    # Filter chip map to only the gratings and their locations, sizes
    chip_gratings = chip_map.get("gratings", None)

    feature_labels = image_feature_details['Label'].unique()
    feature_labels = [l.lower() for l in feature_labels]
    chip_labels = [l for l in chip_map["labels"]
                if l["label"].lower() in feature_labels]

    locs = []
    for chip_label in chip_labels:
        mask = image_feature_details['Label'] == chip_label["label"]
        last_row = image_feature_details[mask].iloc[-1]
        locs.append((last_row['x'], last_row['y']))

    # Use 'translate_vector' to calculate translation vector to move the chip labels to the feature labels
    # Note: Chip labels location must be scaled before calculating the translation vector
    coord_offset = translate_vector(locs[0], scale_vector(
        chip_labels[0]["label_origin"], scale_factor))

    # Add translated grating location to chip grating dictionary
    for idx, g in enumerate(chip_gratings):
        chip_gratings[idx]["grating_origin"] = translate_vector(
            coord_offset, scale_vector(g["grating_origin"], scale_factor))

    # Create ROIs for each grating (North and South) using scaled grating sizes
    ROIs = {}
    for g in chip_gratings:
        x, y = g['grating_origin']
        x, y = int(x), int(y)
        if (x < 0 or
            y < 0 or
            x + int(g['x-size'] * scale_factor) > target_shape[1] or
            y + int(g['y-size'] * scale_factor) > target_shape[0]):
            continue
        grating_x_size = int(g['x-size'] * scale_factor)
        grating_y_size = int(g['y-size'] * scale_factor)
        ROIs[f"ROI_{g['label']}_N"] = {
            'label': f'{g['label']}_N',
            'flip': True,
            'coords': [x, y + grating_y_size//2],
            'size': [grating_x_size, grating_y_size//2],
        }
        ROIs[f"ROI_{g['label']}_S"] = {
            'label': f'{g['label']}_S',
            'flip': False,
            'coords': [x, y],
            'size': [grating_x_size, grating_y_size//2],
        }
    ROIs['image_angle'] = image_angle
    with open(ROI_path, 'w') as file:
        json.dump(ROIs, file, indent=4)

    return ROIs

# %% [markdown]
# ### Generate ROI file (ready for analysing)

# %%
expt_path = Path(
    '/Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/20250206')
img_data_json_name = 'image_metadata_SU000001.json'

img_data = pd.read_json(Path(expt_path, img_data_json_name))
img_data = img_data.T.reset_index(drop=True)
img_data.columns = img_data.columns.str.replace(' ', '_').str.lower()
img_data['root_path'] = img_data['root_path'].str.replace('K:/', '')

# for r in img_data.itertuples():
#     print(f"Index: {r.Index}")
#     print(f"Experiment filepath: {r.root_path}")
#     print(f'Image filename: {r.file_path}')
#     print(
#         f'Image filepath: {Path('/Volumes/krauss', r.root_path, r.file_path)}')
#     # img_data.loc[r.Index, 'processed'] = True
#     break

img_path = Path(img_data['root_path'][0], img_data['file_path'][0])
im = cv.imread(img_path, 0)

target = np.fliplr(im)
target_shape = target.shape

user_feature_list_path = Path('FeatureLocation.json')
image_feature_path = Path('ImageFeatures.csv')
chip_map_path = Path('../../ROI_Locator/Label_templates/Chip_map.json')
template_path = Path('../../ROI_Locator/Label_templates/IMECII/IMEC-II_2')
ROI_path = Path('ROI_ChirpArray.json')
user_scale_factor = (0.75, 0.75)  # Template to image (i.e. template larger than image feature)

scale_factor, image_angle, _ = find_all_labels(target, img_data.iloc[0],
                                               user_feature_list_path,
                                               image_feature_path,
                                               chip_map_path, template_path,
                                               user_scale_factor)

ROIs = generate_ROI_file(image_feature_path,
                         user_feature_list_path,
                         chip_map_path,
                         ROI_path,
                         target_shape,
                         scale_factor,
                         image_angle)

# %% [markdown]
# ### Plot ROIs onto image of chip

# %%
image_num = 50
file_path = Path(f'img_{image_num:09d}_Default_000.tif')
root_path = Path('Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/20250206')
img_path = Path(root_path, file_path)

print(file_path)

raw_im = cv.imread(img_path, 0)

im = cv.equalizeHist(raw_im)
im = np.fliplr(im)
print(im.shape)

_, _, chip_map = process_config_files(image_feature_path,
                                      user_feature_list_path,
                                      chip_map_path)

# Filter chip map to only the gratings and their locations, sizes
chip_gratings = chip_map.get("gratings", None)

ROI_path = Path('ROI_ChirpArray.json')
with open(ROI_path, 'r') as file:
    ROIs = json.load(file)

# Extract data from each ROI (using mean and argmax - simple for now)
line_data_A = []
line_data_B = []
for k, v in ROIs.items():
    if k == 'image_angle':
        continue
    x_slice = slice(v['coords'][0], v['coords'][0] + v['size'][0])
    y_slice = slice(v['coords'][1], v['coords'][1] + v['size'][1])
    data = target[y_slice, x_slice]
    if v['flip']:
        data = np.fliplr(data)
    if 'A' in v['label']:
        line_data_A.append(np.mean(data, axis=0))
    else:
        line_data_B.append(np.mean(data, axis=0))

# Display grating locations on the image for visual confirmation
im_color = cv.cvtColor(cv.equalizeHist(im), cv.COLOR_GRAY2BGR)
for k, v in ROIs.items():
    if k == 'image_angle':
        continue
    x, y = v['coords']
    x_size, y_size = v['size']
    color = (255, 0, 0)
    if 'B' in v['label']:
        color = (0, 255, 0)
    cv.rectangle(im_color, (x, y + y_size), (x + x_size, y), color, 2)
    cv.putText(im_color, v['label'], (x, y + 30),
                cv.FONT_HERSHEY_SIMPLEX, 1, color, 2)

fig, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.imshow(im_color)
# ax.invert_yaxis()
plt.show()

# Display ROIs on the image for visual confirmation
fig, ax = plt.subplots(14, 11, figsize=(10, 10))
a = ax.ravel()
count = 0
for k, v in ROIs.items():
    if k == 'image_angle':
        continue
    x_slice = slice(v['coords'][0], v['coords'][0] + v['size'][0])
    y_slice = slice(v['coords'][1], v['coords'][1] + v['size'][1])
    data = target[y_slice, x_slice]
    if v['flip']:
        data = np.fliplr(data)
    try:
        a[count].imshow(data)
        a[count].set_title(v['label'])
        a[count].invert_yaxis()
        a[count].axis('off')
        count += 1
    except:
        pass
plt.show()
# Out:
# img_000000050_Default_000.tif
# (1460, 1920)
# Error: File not found at ImageFeatures.csv

# %% [markdown]
# ### Measure label locations for all images in experiment
# Used to look for sample drift

# %%
expt_path = Path(
    '/Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/20250206')
img_data_json_name = 'image_metadata_SU000001.json'

img_data = pd.read_json(Path(expt_path, img_data_json_name))
img_data = img_data.T.reset_index(drop=True)
img_data.columns = img_data.columns.str.replace(' ', '_').str.lower()
img_data['root_path'] = img_data['root_path'].str.replace('K:/', '')

user_feature_list_path = Path('FeatureLocation.json')
image_feature_path = Path('ImageFeatures.csv')
chip_map_path = Path('../../ROI_Locator/Label_templates/Chip_map.json')
template_path = Path('../../ROI_Locator/Label_templates/IMECII/IMEC-II_2')
ROI_path = Path('ROI_ChirpArray.json')
# Scale factor for template to image (i.e. template larger than image feature)
user_scale_factor = (0.75, 0.75)

image_feature_list = []
for _, row in img_data.iterrows():
    print(f'Index: {row.Index} \t Image filename: {row.file_path}')
    # img_data.loc[r.Index, 'processed'] = True

    img_path = Path(row.root_path, row.file_path)
    im = cv.imread(img_path, 0)

    target = np.fliplr(im)
    target_shape = target.shape

    scale_factor, image_angle, features = find_all_labels(target, row,
                                                user_feature_list_path,
                                                image_feature_path,
                                                chip_map_path, template_path,
                                                user_scale_factor)

    image_feature_list.append(features)
    break
image_feature_details = pd.concat(image_feature_list, ignore_index=True)
image_feature_details.to_csv(image_feature_path, index=False)
# Out:
# Index: 0 	 Image filename: img_000000000_Default_000.tif
# Index: 1 	 Image filename: img_000000001_Default_000.tif
# Index: 2 	 Image filename: img_000000002_Default_000.tif
# Index: 3 	 Image filename: img_000000003_Default_000.tif
# Index: 4 	 Image filename: img_000000004_Default_000.tif
# Index: 5 	 Image filename: img_000000005_Default_000.tif
# Index: 6 	 Image filename: img_000000006_Default_000.tif
# Index: 7 	 Image filename: img_000000007_Default_000.tif
# Index: 8 	 Image filename: img_000000008_Default_000.tif
# Index: 9 	 Image filename: img_000000009_Default_000.tif
# Index: 10 	 Image filename: img_000000010_Default_000.tif
# Index: 11 	 Image filename: img_000000011_Default_000.tif
# Index: 12 	 Image filename: img_000000012_Default_000.tif
# Index: 13 	 Image filename: img_000000013_Default_000.tif
# Index: 14 	 Image filename: img_000000014_Default_000.tif
# Index: 15 	 Image filename: img_000000015_Default_000.tif
# Index: 16 	 Image filename: img_000000016_Default_000.tif
# Index: 17 	 Image filename: img_000000017_Default_000.tif
# Index: 18 	 Image filename: img_000000018_Default_000.tif
# Index: 19 	 Image filename: img_000000019_Default_000.tif
# Index: 20 	 Image filename: img_000000020_Default_000.tif
# Index: 21 	 Image filename: img_000000021_Default_000.tif
# Index: 22 	 Image filename: img_000000022_Default_000.tif
# Index: 23 	 Image filename: img_000000023_Default_000.tif
# Index: 24 	 Image filename: img_000000024_Default_000.tif
# Index: 25 	 Image filename: img_000000025_Default_000.tif
# Index: 26 	 Image filename: img_000000026_Default_000.tif
# Index: 27 	 Image filename: img_000000027_Default_000.tif
# Index: 28 	 Image filename: img_000000028_Default_000.tif
# Index: 29 	 Image filename: img_000000029_Default_000.tif
# Index: 30 	 Image filename: img_000000030_Default_000.tif
# Index: 31 	 Image filename: img_000000031_Default_000.tif
# Index: 32 	 Image filename: img_000000032_Default_000.tif
# Index: 33 	 Image filename: img_000000033_Default_000.tif
# Index: 34 	 Image filename: img_000000034_Default_000.tif
# Index: 35 	 Image filename: img_000000035_Default_000.tif
# Index: 36 	 Image filename: img_000000036_Default_000.tif
# Index: 37 	 Image filename: img_000000037_Default_000.tif
# Index: 38 	 Image filename: img_000000038_Default_000.tif
# Index: 39 	 Image filename: img_000000039_Default_000.tif
# Index: 40 	 Image filename: img_000000040_Default_000.tif
# Index: 41 	 Image filename: img_000000041_Default_000.tif
# Index: 42 	 Image filename: img_000000042_Default_000.tif
# Index: 43 	 Image filename: img_000000043_Default_000.tif
# Index: 44 	 Image filename: img_000000044_Default_000.tif
# Index: 45 	 Image filename: img_000000045_Default_000.tif
# Index: 46 	 Image filename: img_000000046_Default_000.tif
# Index: 47 	 Image filename: img_000000047_Default_000.tif
# Index: 48 	 Image filename: img_000000048_Default_000.tif
# Index: 49 	 Image filename: img_000000049_Default_000.tif
# Index: 50 	 Image filename: img_000000050_Default_000.tif
# Index: 51 	 Image filename: img_000000051_Default_000.tif
# Index: 52 	 Image filename: img_000000052_Default_000.tif
# Index: 53 	 Image filename: img_000000053_Default_000.tif
# Index: 54 	 Image filename: img_000000054_Default_000.tif
# Index: 55 	 Image filename: img_000000055_Default_000.tif
# Index: 56 	 Image filename: img_000000056_Default_000.tif
# Index: 57 	 Image filename: img_000000057_Default_000.tif
# Index: 58 	 Image filename: img_000000058_Default_000.tif
# Index: 59 	 Image filename: img_000000059_Default_000.tif
# Index: 60 	 Image filename: img_000000060_Default_000.tif
# Index: 61 	 Image filename: img_000000061_Default_000.tif
# Index: 62 	 Image filename: img_000000062_Default_000.tif
# Index: 63 	 Image filename: img_000000063_Default_000.tif
# Index: 64 	 Image filename: img_000000064_Default_000.tif
# Index: 65 	 Image filename: img_000000065_Default_000.tif
# Index: 66 	 Image filename: img_000000066_Default_000.tif
# Index: 67 	 Image filename: img_000000067_Default_000.tif
# Index: 68 	 Image filename: img_000000068_Default_000.tif
# Index: 69 	 Image filename: img_000000069_Default_000.tif
# Index: 70 	 Image filename: img_000000070_Default_000.tif
# Index: 71 	 Image filename: img_000000071_Default_000.tif
# Index: 72 	 Image filename: img_000000072_Default_000.tif
# Index: 73 	 Image filename: img_000000073_Default_000.tif
# Index: 74 	 Image filename: img_000000074_Default_000.tif
# Index: 75 	 Image filename: img_000000075_Default_000.tif
# Index: 76 	 Image filename: img_000000076_Default_000.tif
# Index: 77 	 Image filename: img_000000077_Default_000.tif
# Index: 78 	 Image filename: img_000000078_Default_000.tif
# Index: 79 	 Image filename: img_000000079_Default_000.tif
# Index: 80 	 Image filename: img_000000080_Default_000.tif
# Index: 81 	 Image filename: img_000000081_Default_000.tif
# Index: 82 	 Image filename: img_000000082_Default_000.tif
# Index: 83 	 Image filename: img_000000083_Default_000.tif
# Index: 84 	 Image filename: img_000000084_Default_000.tif
# Index: 85 	 Image filename: img_000000085_Default_000.tif
# Index: 86 	 Image filename: img_000000086_Default_000.tif
# Index: 87 	 Image filename: img_000000087_Default_000.tif
# Index: 88 	 Image filename: img_000000088_Default_000.tif
# Index: 89 	 Image filename: img_000000089_Default_000.tif
# Index: 90 	 Image filename: img_000000090_Default_000.tif
# Index: 91 	 Image filename: img_000000091_Default_000.tif
# Index: 92 	 Image filename: img_000000092_Default_000.tif
# Index: 93 	 Image filename: img_000000093_Default_000.tif
# Index: 94 	 Image filename: img_000000094_Default_000.tif
# Index: 95 	 Image filename: img_000000095_Default_000.tif
# Index: 96 	 Image filename: img_000000096_Default_000.tif
# Index: 97 	 Image filename: img_000000097_Default_000.tif
# Index: 98 	 Image filename: img_000000098_Default_000.tif
# Index: 99 	 Image filename: img_000000099_Default_000.tif
# Index: 100 	 Image filename: img_000000100_Default_000.tif
# Index: 101 	 Image filename: img_000000101_Default_000.tif
# Index: 102 	 Image filename: img_000000102_Default_000.tif
# Index: 103 	 Image filename: img_000000103_Default_000.tif
# Index: 104 	 Image filename: img_000000104_Default_000.tif
# Index: 105 	 Image filename: img_000000105_Default_000.tif
# Index: 106 	 Image filename: img_000000106_Default_000.tif
# Index: 107 	 Image filename: img_000000107_Default_000.tif
# Index: 108 	 Image filename: img_000000108_Default_000.tif
# Index: 109 	 Image filename: img_000000109_Default_000.tif
# Index: 110 	 Image filename: img_000000110_Default_000.tif
# Index: 111 	 Image filename: img_000000111_Default_000.tif
# Index: 112 	 Image filename: img_000000112_Default_000.tif
# Index: 113 	 Image filename: img_000000113_Default_000.tif
# Index: 114 	 Image filename: img_000000114_Default_000.tif
# Index: 115 	 Image filename: img_000000115_Default_000.tif
# Index: 116 	 Image filename: img_000000116_Default_000.tif
# Index: 117 	 Image filename: img_000000117_Default_000.tif
# Index: 118 	 Image filename: img_000000118_Default_000.tif
# Index: 119 	 Image filename: img_000000119_Default_000.tif
# Index: 120 	 Image filename: img_000000120_Default_000.tif
# Index: 121 	 Image filename: img_000000121_Default_000.tif
# Index: 122 	 Image filename: img_000000122_Default_000.tif
# Index: 123 	 Image filename: img_000000123_Default_000.tif
# Index: 124 	 Image filename: img_000000124_Default_000.tif
# Index: 125 	 Image filename: img_000000125_Default_000.tif
# Index: 126 	 Image filename: img_000000126_Default_000.tif
# Index: 127 	 Image filename: img_000000127_Default_000.tif
# Index: 128 	 Image filename: img_000000128_Default_000.tif
# Index: 129 	 Image filename: img_000000129_Default_000.tif
# Index: 130 	 Image filename: img_000000130_Default_000.tif
# Index: 131 	 Image filename: img_000000131_Default_000.tif
# Index: 132 	 Image filename: img_000000132_Default_000.tif
# Index: 133 	 Image filename: img_000000133_Default_000.tif
# Index: 134 	 Image filename: img_000000134_Default_000.tif
# Index: 135 	 Image filename: img_000000135_Default_000.tif
# Index: 136 	 Image filename: img_000000136_Default_000.tif
# Index: 137 	 Image filename: img_000000137_Default_000.tif
# Index: 138 	 Image filename: img_000000138_Default_000.tif
# Index: 139 	 Image filename: img_000000139_Default_000.tif
# Index: 140 	 Image filename: img_000000140_Default_000.tif
# Index: 141 	 Image filename: img_000000141_Default_000.tif
# Index: 142 	 Image filename: img_000000142_Default_000.tif
# Index: 143 	 Image filename: img_000000143_Default_000.tif
# Index: 144 	 Image filename: img_000000144_Default_000.tif
# Index: 145 	 Image filename: img_000000145_Default_000.tif
# Index: 146 	 Image filename: img_000000146_Default_000.tif
# Index: 147 	 Image filename: img_000000147_Default_000.tif
# Index: 148 	 Image filename: img_000000148_Default_000.tif
# Index: 149 	 Image filename: img_000000149_Default_000.tif
# Index: 150 	 Image filename: img_000000150_Default_000.tif
# Index: 151 	 Image filename: img_000000151_Default_000.tif
# Index: 152 	 Image filename: img_000000152_Default_000.tif
# Index: 153 	 Image filename: img_000000153_Default_000.tif
# Index: 154 	 Image filename: img_000000154_Default_000.tif
# Index: 155 	 Image filename: img_000000155_Default_000.tif
# Index: 156 	 Image filename: img_000000156_Default_000.tif
# Index: 157 	 Image filename: img_000000157_Default_000.tif
# Index: 158 	 Image filename: img_000000158_Default_000.tif
# Index: 159 	 Image filename: img_000000159_Default_000.tif
# Index: 160 	 Image filename: img_000000160_Default_000.tif
# Index: 161 	 Image filename: img_000000161_Default_000.tif
# Index: 162 	 Image filename: img_000000162_Default_000.tif
# Index: 163 	 Image filename: img_000000163_Default_000.tif
# Index: 164 	 Image filename: img_000000164_Default_000.tif
# Index: 165 	 Image filename: img_000000165_Default_000.tif
# Index: 166 	 Image filename: img_000000166_Default_000.tif
# Index: 167 	 Image filename: img_000000167_Default_000.tif
# Index: 168 	 Image filename: img_000000168_Default_000.tif
# Index: 169 	 Image filename: img_000000169_Default_000.tif
# Index: 170 	 Image filename: img_000000170_Default_000.tif
# Index: 171 	 Image filename: img_000000171_Default_000.tif
# Index: 172 	 Image filename: img_000000172_Default_000.tif
# Index: 173 	 Image filename: img_000000173_Default_000.tif
# Index: 174 	 Image filename: img_000000174_Default_000.tif
# Index: 175 	 Image filename: img_000000175_Default_000.tif
# Index: 176 	 Image filename: img_000000176_Default_000.tif
# Index: 177 	 Image filename: img_000000177_Default_000.tif
# Index: 178 	 Image filename: img_000000178_Default_000.tif
# Index: 179 	 Image filename: img_000000179_Default_000.tif
# Index: 180 	 Image filename: img_000000180_Default_000.tif
# Index: 181 	 Image filename: img_000000181_Default_000.tif
# Index: 182 	 Image filename: img_000000182_Default_000.tif
# Index: 183 	 Image filename: img_000000183_Default_000.tif
# Index: 184 	 Image filename: img_000000184_Default_000.tif
# Index: 185 	 Image filename: img_000000185_Default_000.tif
# Index: 186 	 Image filename: img_000000186_Default_000.tif
# Index: 187 	 Image filename: img_000000187_Default_000.tif
# Index: 188 	 Image filename: img_000000188_Default_000.tif
# Index: 189 	 Image filename: img_000000189_Default_000.tif
# Index: 190 	 Image filename: img_000000190_Default_000.tif
# Index: 191 	 Image filename: img_000000191_Default_000.tif
# Index: 192 	 Image filename: img_000000192_Default_000.tif
# Index: 193 	 Image filename: img_000000193_Default_000.tif
# Index: 194 	 Image filename: img_000000194_Default_000.tif
# Index: 195 	 Image filename: img_000000195_Default_000.tif
# Index: 196 	 Image filename: img_000000196_Default_000.tif
# Index: 197 	 Image filename: img_000000197_Default_000.tif
# Index: 198 	 Image filename: img_000000198_Default_000.tif
# Index: 199 	 Image filename: img_000000199_Default_000.tif
# Index: 200 	 Image filename: img_000000200_Default_000.tif
# Index: 201 	 Image filename: img_000000201_Default_000.tif
# Index: 202 	 Image filename: img_000000202_Default_000.tif
# Index: 203 	 Image filename: img_000000203_Default_000.tif
# Index: 204 	 Image filename: img_000000204_Default_000.tif
# Index: 205 	 Image filename: img_000000205_Default_000.tif
# Index: 206 	 Image filename: img_000000206_Default_000.tif
# Index: 207 	 Image filename: img_000000207_Default_000.tif
# Index: 208 	 Image filename: img_000000208_Default_000.tif
# Index: 209 	 Image filename: img_000000209_Default_000.tif
# Index: 210 	 Image filename: img_000000210_Default_000.tif
# Index: 211 	 Image filename: img_000000211_Default_000.tif
# Index: 212 	 Image filename: img_000000212_Default_000.tif
# Index: 213 	 Image filename: img_000000213_Default_000.tif
# Index: 214 	 Image filename: img_000000214_Default_000.tif
# Index: 215 	 Image filename: img_000000215_Default_000.tif
# Index: 216 	 Image filename: img_000000216_Default_000.tif
# Index: 217 	 Image filename: img_000000217_Default_000.tif
# Index: 218 	 Image filename: img_000000218_Default_000.tif
# Index: 219 	 Image filename: img_000000219_Default_000.tif
# Index: 220 	 Image filename: img_000000220_Default_000.tif
# Index: 221 	 Image filename: img_000000221_Default_000.tif
# Index: 222 	 Image filename: img_000000222_Default_000.tif
# Index: 223 	 Image filename: img_000000223_Default_000.tif
# Index: 224 	 Image filename: img_000000224_Default_000.tif
# Index: 225 	 Image filename: img_000000225_Default_000.tif
# Index: 226 	 Image filename: img_000000226_Default_000.tif
# Index: 227 	 Image filename: img_000000227_Default_000.tif
# Index: 228 	 Image filename: img_000000228_Default_000.tif
# Index: 229 	 Image filename: img_000000229_Default_000.tif
# Index: 230 	 Image filename: img_000000230_Default_000.tif
# Index: 231 	 Image filename: img_000000231_Default_000.tif
# Index: 232 	 Image filename: img_000000232_Default_000.tif
# Index: 233 	 Image filename: img_000000233_Default_000.tif
# Index: 234 	 Image filename: img_000000234_Default_000.tif
# Index: 235 	 Image filename: img_000000235_Default_000.tif
# Index: 236 	 Image filename: img_000000236_Default_000.tif
# Index: 237 	 Image filename: img_000000237_Default_000.tif
# Index: 238 	 Image filename: img_000000238_Default_000.tif
# Index: 239 	 Image filename: img_000000239_Default_000.tif
# Index: 240 	 Image filename: img_000000240_Default_000.tif
# Index: 241 	 Image filename: img_000000241_Default_000.tif
# Index: 242 	 Image filename: img_000000242_Default_000.tif
# Index: 243 	 Image filename: img_000000243_Default_000.tif
# Index: 244 	 Image filename: img_000000244_Default_000.tif
# Index: 245 	 Image filename: img_000000245_Default_000.tif
# Index: 246 	 Image filename: img_000000246_Default_000.tif
# Index: 247 	 Image filename: img_000000247_Default_000.tif
# Index: 248 	 Image filename: img_000000248_Default_000.tif
# Index: 249 	 Image filename: img_000000249_Default_000.tif
# Index: 250 	 Image filename: img_000000250_Default_000.tif
# Index: 251 	 Image filename: img_000000251_Default_000.tif
# Index: 252 	 Image filename: img_000000252_Default_000.tif
# Index: 253 	 Image filename: img_000000253_Default_000.tif
# Index: 254 	 Image filename: img_000000254_Default_000.tif
# Index: 255 	 Image filename: img_000000255_Default_000.tif
# Index: 256 	 Image filename: img_000000256_Default_000.tif
# Index: 257 	 Image filename: img_000000257_Default_000.tif
# Index: 258 	 Image filename: img_000000258_Default_000.tif
# Index: 259 	 Image filename: img_000000259_Default_000.tif
# Index: 260 	 Image filename: img_000000260_Default_000.tif
# Index: 261 	 Image filename: img_000000261_Default_000.tif
# Index: 262 	 Image filename: img_000000262_Default_000.tif
# Index: 263 	 Image filename: img_000000263_Default_000.tif
# Index: 264 	 Image filename: img_000000264_Default_000.tif
# Index: 265 	 Image filename: img_000000265_Default_000.tif
# Index: 266 	 Image filename: img_000000266_Default_000.tif
# Index: 267 	 Image filename: img_000000267_Default_000.tif
# Index: 268 	 Image filename: img_000000268_Default_000.tif
# Index: 269 	 Image filename: img_000000269_Default_000.tif
# Index: 270 	 Image filename: img_000000270_Default_000.tif
# Index: 271 	 Image filename: img_000000271_Default_000.tif
# Index: 272 	 Image filename: img_000000272_Default_000.tif
# Index: 273 	 Image filename: img_000000273_Default_000.tif
# Index: 274 	 Image filename: img_000000274_Default_000.tif
# Index: 275 	 Image filename: img_000000275_Default_000.tif
# Index: 276 	 Image filename: img_000000276_Default_000.tif
# Index: 277 	 Image filename: img_000000277_Default_000.tif
# Index: 278 	 Image filename: img_000000278_Default_000.tif
# Index: 279 	 Image filename: img_000000279_Default_000.tif
# Index: 280 	 Image filename: img_000000280_Default_000.tif
# Index: 281 	 Image filename: img_000000281_Default_000.tif
# Index: 282 	 Image filename: img_000000282_Default_000.tif
# Index: 283 	 Image filename: img_000000283_Default_000.tif
# Index: 284 	 Image filename: img_000000284_Default_000.tif
# Index: 285 	 Image filename: img_000000285_Default_000.tif
# Index: 286 	 Image filename: img_000000286_Default_000.tif
# Index: 287 	 Image filename: img_000000287_Default_000.tif
# Index: 288 	 Image filename: img_000000288_Default_000.tif
# Index: 289 	 Image filename: img_000000289_Default_000.tif
# Index: 290 	 Image filename: img_000000290_Default_000.tif
# Index: 291 	 Image filename: img_000000291_Default_000.tif
# Index: 292 	 Image filename: img_000000292_Default_000.tif
# Index: 293 	 Image filename: img_000000293_Default_000.tif
# Index: 294 	 Image filename: img_000000294_Default_000.tif
# Index: 295 	 Image filename: img_000000295_Default_000.tif
# Index: 296 	 Image filename: img_000000296_Default_000.tif
# Index: 297 	 Image filename: img_000000297_Default_000.tif
# Index: 298 	 Image filename: img_000000298_Default_000.tif
# Index: 299 	 Image filename: img_000000299_Default_000.tif
# Index: 300 	 Image filename: img_000000300_Default_000.tif
# Index: 301 	 Image filename: img_000000301_Default_000.tif
# Index: 302 	 Image filename: img_000000302_Default_000.tif
# Index: 303 	 Image filename: img_000000303_Default_000.tif
# Index: 304 	 Image filename: img_000000304_Default_000.tif
# Index: 305 	 Image filename: img_000000305_Default_000.tif
# Index: 306 	 Image filename: img_000000306_Default_000.tif
# Index: 307 	 Image filename: img_000000307_Default_000.tif
# Index: 308 	 Image filename: img_000000308_Default_000.tif
# Index: 309 	 Image filename: img_000000309_Default_000.tif
# Index: 310 	 Image filename: img_000000310_Default_000.tif
# Index: 311 	 Image filename: img_000000311_Default_000.tif
# Index: 312 	 Image filename: img_000000312_Default_000.tif
# Index: 313 	 Image filename: img_000000313_Default_000.tif
# Index: 314 	 Image filename: img_000000314_Default_000.tif
# Index: 315 	 Image filename: img_000000315_Default_000.tif
# Index: 316 	 Image filename: img_000000316_Default_000.tif
# Index: 317 	 Image filename: img_000000317_Default_000.tif
# Index: 318 	 Image filename: img_000000318_Default_000.tif
# Index: 319 	 Image filename: img_000000319_Default_000.tif
# Index: 320 	 Image filename: img_000000320_Default_000.tif
# Index: 321 	 Image filename: img_000000321_Default_000.tif
# Index: 322 	 Image filename: img_000000322_Default_000.tif
# Index: 323 	 Image filename: img_000000323_Default_000.tif
# Index: 324 	 Image filename: img_000000324_Default_000.tif
# Index: 325 	 Image filename: img_000000325_Default_000.tif
# Index: 326 	 Image filename: img_000000326_Default_000.tif
# Index: 327 	 Image filename: img_000000327_Default_000.tif
# Index: 328 	 Image filename: img_000000328_Default_000.tif
# Index: 329 	 Image filename: img_000000329_Default_000.tif
# Index: 330 	 Image filename: img_000000330_Default_000.tif
# Index: 331 	 Image filename: img_000000331_Default_000.tif
# Index: 332 	 Image filename: img_000000332_Default_000.tif
# Index: 333 	 Image filename: img_000000333_Default_000.tif
# Index: 334 	 Image filename: img_000000334_Default_000.tif
# Index: 335 	 Image filename: img_000000335_Default_000.tif
# Index: 336 	 Image filename: img_000000336_Default_000.tif
# Index: 337 	 Image filename: img_000000337_Default_000.tif
# Index: 338 	 Image filename: img_000000338_Default_000.tif
# Index: 339 	 Image filename: img_000000339_Default_000.tif
# Index: 340 	 Image filename: img_000000340_Default_000.tif
# Index: 341 	 Image filename: img_000000341_Default_000.tif
# Index: 342 	 Image filename: img_000000342_Default_000.tif
# Index: 343 	 Image filename: img_000000343_Default_000.tif
# Index: 344 	 Image filename: img_000000344_Default_000.tif
# Index: 345 	 Image filename: img_000000345_Default_000.tif
# Index: 346 	 Image filename: img_000000346_Default_000.tif
# Index: 347 	 Image filename: img_000000347_Default_000.tif
# Index: 348 	 Image filename: img_000000348_Default_000.tif
# Index: 349 	 Image filename: img_000000349_Default_000.tif
# Index: 350 	 Image filename: img_000000350_Default_000.tif
# Index: 351 	 Image filename: img_000000351_Default_000.tif
# Index: 352 	 Image filename: img_000000352_Default_000.tif
# Index: 353 	 Image filename: img_000000353_Default_000.tif
# Index: 354 	 Image filename: img_000000354_Default_000.tif
# Index: 355 	 Image filename: img_000000355_Default_000.tif
# Index: 356 	 Image filename: img_000000356_Default_000.tif
# Index: 357 	 Image filename: img_000000357_Default_000.tif
# Index: 358 	 Image filename: img_000000358_Default_000.tif
# Index: 359 	 Image filename: img_000000359_Default_000.tif
# Index: 360 	 Image filename: img_000000360_Default_000.tif
# Index: 361 	 Image filename: img_000000361_Default_000.tif
# Index: 362 	 Image filename: img_000000362_Default_000.tif
# Index: 363 	 Image filename: img_000000363_Default_000.tif
# Index: 364 	 Image filename: img_000000364_Default_000.tif
# Index: 365 	 Image filename: img_000000365_Default_000.tif
# Index: 366 	 Image filename: img_000000366_Default_000.tif
# Index: 367 	 Image filename: img_000000367_Default_000.tif
# Index: 368 	 Image filename: img_000000368_Default_000.tif
# Index: 369 	 Image filename: img_000000369_Default_000.tif
# Index: 370 	 Image filename: img_000000370_Default_000.tif
# Index: 371 	 Image filename: img_000000371_Default_000.tif
# Index: 372 	 Image filename: img_000000372_Default_000.tif
# Index: 373 	 Image filename: img_000000373_Default_000.tif
# Index: 374 	 Image filename: img_000000374_Default_000.tif
# Index: 375 	 Image filename: img_000000375_Default_000.tif
# Index: 376 	 Image filename: img_000000376_Default_000.tif
# Index: 377 	 Image filename: img_000000377_Default_000.tif
# Index: 378 	 Image filename: img_000000378_Default_000.tif
# Index: 379 	 Image filename: img_000000379_Default_000.tif
# Index: 380 	 Image filename: img_000000380_Default_000.tif
# Index: 381 	 Image filename: img_000000381_Default_000.tif
# Index: 382 	 Image filename: img_000000382_Default_000.tif
# Index: 383 	 Image filename: img_000000383_Default_000.tif
# Index: 384 	 Image filename: img_000000384_Default_000.tif
# Index: 385 	 Image filename: img_000000385_Default_000.tif
# Index: 386 	 Image filename: img_000000386_Default_000.tif
# Index: 387 	 Image filename: img_000000387_Default_000.tif
# Index: 388 	 Image filename: img_000000388_Default_000.tif
# Index: 389 	 Image filename: img_000000389_Default_000.tif
# Index: 390 	 Image filename: img_000000390_Default_000.tif
# Index: 391 	 Image filename: img_000000391_Default_000.tif
# Index: 392 	 Image filename: img_000000392_Default_000.tif
# Index: 393 	 Image filename: img_000000393_Default_000.tif
# Index: 394 	 Image filename: img_000000394_Default_000.tif
# Index: 395 	 Image filename: img_000000395_Default_000.tif
# Index: 396 	 Image filename: img_000000396_Default_000.tif
# Index: 397 	 Image filename: img_000000397_Default_000.tif
# Index: 398 	 Image filename: img_000000398_Default_000.tif
# Index: 399 	 Image filename: img_000000399_Default_000.tif
# Index: 400 	 Image filename: img_000000400_Default_000.tif
# Index: 401 	 Image filename: img_000000401_Default_000.tif
# Index: 402 	 Image filename: img_000000402_Default_000.tif
# Index: 403 	 Image filename: img_000000403_Default_000.tif
# Index: 404 	 Image filename: img_000000404_Default_000.tif
# Index: 405 	 Image filename: img_000000405_Default_000.tif
# Index: 406 	 Image filename: img_000000406_Default_000.tif
# Index: 407 	 Image filename: img_000000407_Default_000.tif
# Index: 408 	 Image filename: img_000000408_Default_000.tif
# Index: 409 	 Image filename: img_000000409_Default_000.tif
# Index: 410 	 Image filename: img_000000410_Default_000.tif
# Index: 411 	 Image filename: img_000000411_Default_000.tif
# Index: 412 	 Image filename: img_000000412_Default_000.tif
# Index: 413 	 Image filename: img_000000413_Default_000.tif
# Index: 414 	 Image filename: img_000000414_Default_000.tif
# Index: 415 	 Image filename: img_000000415_Default_000.tif
# Index: 416 	 Image filename: img_000000416_Default_000.tif
# Index: 417 	 Image filename: img_000000417_Default_000.tif
# Index: 418 	 Image filename: img_000000418_Default_000.tif
# Index: 419 	 Image filename: img_000000419_Default_000.tif
# Index: 420 	 Image filename: img_000000420_Default_000.tif
# Index: 421 	 Image filename: img_000000421_Default_000.tif
# Index: 422 	 Image filename: img_000000422_Default_000.tif
# Index: 423 	 Image filename: img_000000423_Default_000.tif
# Index: 424 	 Image filename: img_000000424_Default_000.tif
# Index: 425 	 Image filename: img_000000425_Default_000.tif
# Index: 426 	 Image filename: img_000000426_Default_000.tif
# Index: 427 	 Image filename: img_000000427_Default_000.tif
# Index: 428 	 Image filename: img_000000428_Default_000.tif
# Index: 429 	 Image filename: img_000000429_Default_000.tif
# Index: 430 	 Image filename: img_000000430_Default_000.tif
# Index: 431 	 Image filename: img_000000431_Default_000.tif
# Index: 432 	 Image filename: img_000000432_Default_000.tif
# Index: 433 	 Image filename: img_000000433_Default_000.tif
# Index: 434 	 Image filename: img_000000434_Default_000.tif
# Index: 435 	 Image filename: img_000000435_Default_000.tif
# Index: 436 	 Image filename: img_000000436_Default_000.tif
# Index: 437 	 Image filename: img_000000437_Default_000.tif
# Index: 438 	 Image filename: img_000000438_Default_000.tif
# Index: 439 	 Image filename: img_000000439_Default_000.tif
# Index: 440 	 Image filename: img_000000440_Default_000.tif
# Index: 441 	 Image filename: img_000000441_Default_000.tif
# Index: 442 	 Image filename: img_000000442_Default_000.tif
# Index: 443 	 Image filename: img_000000443_Default_000.tif
# Index: 444 	 Image filename: img_000000444_Default_000.tif
# Index: 445 	 Image filename: img_000000445_Default_000.tif
# Index: 446 	 Image filename: img_000000446_Default_000.tif
# Index: 447 	 Image filename: img_000000447_Default_000.tif
# Index: 448 	 Image filename: img_000000448_Default_000.tif
# Index: 449 	 Image filename: img_000000449_Default_000.tif
# Index: 450 	 Image filename: img_000000450_Default_000.tif
# Index: 451 	 Image filename: img_000000451_Default_000.tif
# Index: 452 	 Image filename: img_000000452_Default_000.tif
# Index: 453 	 Image filename: img_000000453_Default_000.tif
# Index: 454 	 Image filename: img_000000454_Default_000.tif
# Index: 455 	 Image filename: img_000000455_Default_000.tif
# Index: 456 	 Image filename: img_000000456_Default_000.tif
# Index: 457 	 Image filename: img_000000457_Default_000.tif
# Index: 458 	 Image filename: img_000000458_Default_000.tif
# Index: 459 	 Image filename: img_000000459_Default_000.tif
# Index: 460 	 Image filename: img_000000460_Default_000.tif
# Index: 461 	 Image filename: img_000000461_Default_000.tif
# Index: 462 	 Image filename: img_000000462_Default_000.tif
# Index: 463 	 Image filename: img_000000463_Default_000.tif
# Index: 464 	 Image filename: img_000000464_Default_000.tif
# Index: 465 	 Image filename: img_000000465_Default_000.tif
# Index: 466 	 Image filename: img_000000466_Default_000.tif
# Index: 467 	 Image filename: img_000000467_Default_000.tif
# Index: 468 	 Image filename: img_000000468_Default_000.tif
# Index: 469 	 Image filename: img_000000469_Default_000.tif
# Index: 470 	 Image filename: img_000000470_Default_000.tif
# Index: 471 	 Image filename: img_000000471_Default_000.tif
# Index: 472 	 Image filename: img_000000472_Default_000.tif
# Index: 473 	 Image filename: img_000000473_Default_000.tif
# Index: 474 	 Image filename: img_000000474_Default_000.tif
# Index: 475 	 Image filename: img_000000475_Default_000.tif
# Index: 476 	 Image filename: img_000000476_Default_000.tif
# Index: 477 	 Image filename: img_000000477_Default_000.tif
# Index: 478 	 Image filename: img_000000478_Default_000.tif
# Index: 479 	 Image filename: img_000000479_Default_000.tif
# Index: 480 	 Image filename: img_000000480_Default_000.tif
# Index: 481 	 Image filename: img_000000481_Default_000.tif
# Index: 482 	 Image filename: img_000000482_Default_000.tif
# Index: 483 	 Image filename: img_000000483_Default_000.tif
# Index: 484 	 Image filename: img_000000484_Default_000.tif
# Index: 485 	 Image filename: img_000000485_Default_000.tif
# Index: 486 	 Image filename: img_000000486_Default_000.tif
# Index: 487 	 Image filename: img_000000487_Default_000.tif
# Index: 488 	 Image filename: img_000000488_Default_000.tif
# Index: 489 	 Image filename: img_000000489_Default_000.tif
# Index: 490 	 Image filename: img_000000490_Default_000.tif
# Index: 491 	 Image filename: img_000000491_Default_000.tif
# Index: 492 	 Image filename: img_000000492_Default_000.tif
# Index: 493 	 Image filename: img_000000493_Default_000.tif
# Index: 494 	 Image filename: img_000000494_Default_000.tif
# Index: 495 	 Image filename: img_000000495_Default_000.tif
# Index: 496 	 Image filename: img_000000496_Default_000.tif
# Index: 497 	 Image filename: img_000000497_Default_000.tif
# Index: 498 	 Image filename: img_000000498_Default_000.tif
# Index: 499 	 Image filename: img_000000499_Default_000.tif
# Index: 500 	 Image filename: img_000000500_Default_000.tif
# Index: 501 	 Image filename: img_000000501_Default_000.tif
# Index: 502 	 Image filename: img_000000502_Default_000.tif
# Index: 503 	 Image filename: img_000000503_Default_000.tif
# Index: 504 	 Image filename: img_000000504_Default_000.tif
# Index: 505 	 Image filename: img_000000505_Default_000.tif
# Index: 506 	 Image filename: img_000000506_Default_000.tif
# Index: 507 	 Image filename: img_000000507_Default_000.tif
# Index: 508 	 Image filename: img_000000508_Default_000.tif
# Index: 509 	 Image filename: img_000000509_Default_000.tif
# Index: 510 	 Image filename: img_000000510_Default_000.tif
# Index: 511 	 Image filename: img_000000511_Default_000.tif
# Index: 512 	 Image filename: img_000000512_Default_000.tif
# Index: 513 	 Image filename: img_000000513_Default_000.tif
# Index: 514 	 Image filename: img_000000514_Default_000.tif
# Index: 515 	 Image filename: img_000000515_Default_000.tif
# Index: 516 	 Image filename: img_000000516_Default_000.tif
# Index: 517 	 Image filename: img_000000517_Default_000.tif
# Index: 518 	 Image filename: img_000000518_Default_000.tif
# Index: 519 	 Image filename: img_000000519_Default_000.tif
# Index: 520 	 Image filename: img_000000520_Default_000.tif
# Index: 521 	 Image filename: img_000000521_Default_000.tif
# Index: 522 	 Image filename: img_000000522_Default_000.tif
# Index: 523 	 Image filename: img_000000523_Default_000.tif
# Index: 524 	 Image filename: img_000000524_Default_000.tif
# Index: 525 	 Image filename: img_000000525_Default_000.tif
# Index: 526 	 Image filename: img_000000526_Default_000.tif
# Index: 527 	 Image filename: img_000000527_Default_000.tif
# Index: 528 	 Image filename: img_000000528_Default_000.tif
# Index: 529 	 Image filename: img_000000529_Default_000.tif
# Index: 530 	 Image filename: img_000000530_Default_000.tif
# Index: 531 	 Image filename: img_000000531_Default_000.tif
# Index: 532 	 Image filename: img_000000532_Default_000.tif
# Index: 533 	 Image filename: img_000000533_Default_000.tif
# Index: 534 	 Image filename: img_000000534_Default_000.tif
# Index: 535 	 Image filename: img_000000535_Default_000.tif
# Index: 536 	 Image filename: img_000000536_Default_000.tif
# Index: 537 	 Image filename: img_000000537_Default_000.tif
# Index: 538 	 Image filename: img_000000538_Default_000.tif
# Index: 539 	 Image filename: img_000000539_Default_000.tif
# Index: 540 	 Image filename: img_000000540_Default_000.tif
# Index: 541 	 Image filename: img_000000541_Default_000.tif
# Index: 542 	 Image filename: img_000000542_Default_000.tif
# Index: 543 	 Image filename: img_000000543_Default_000.tif
# Index: 544 	 Image filename: img_000000544_Default_000.tif
# Index: 545 	 Image filename: img_000000545_Default_000.tif
# Index: 546 	 Image filename: img_000000546_Default_000.tif
# Index: 547 	 Image filename: img_000000547_Default_000.tif
# Index: 548 	 Image filename: img_000000548_Default_000.tif
# Index: 549 	 Image filename: img_000000549_Default_000.tif
# Index: 550 	 Image filename: img_000000550_Default_000.tif
# Index: 551 	 Image filename: img_000000551_Default_000.tif
# Index: 552 	 Image filename: img_000000552_Default_000.tif
# Index: 553 	 Image filename: img_000000553_Default_000.tif
# Index: 554 	 Image filename: img_000000554_Default_000.tif
# Index: 555 	 Image filename: img_000000555_Default_000.tif
# Index: 556 	 Image filename: img_000000556_Default_000.tif
# Index: 557 	 Image filename: img_000000557_Default_000.tif
# Index: 558 	 Image filename: img_000000558_Default_000.tif
# Index: 559 	 Image filename: img_000000559_Default_000.tif
# Index: 560 	 Image filename: img_000000560_Default_000.tif
# Index: 561 	 Image filename: img_000000561_Default_000.tif
# Index: 562 	 Image filename: img_000000562_Default_000.tif
# Index: 563 	 Image filename: img_000000563_Default_000.tif
# Index: 564 	 Image filename: img_000000564_Default_000.tif
# Index: 565 	 Image filename: img_000000565_Default_000.tif
# Index: 566 	 Image filename: img_000000566_Default_000.tif
# Index: 567 	 Image filename: img_000000567_Default_000.tif
# Index: 568 	 Image filename: img_000000568_Default_000.tif
# Index: 569 	 Image filename: img_000000569_Default_000.tif
# Index: 570 	 Image filename: img_000000570_Default_000.tif
# Index: 571 	 Image filename: img_000000571_Default_000.tif
# Index: 572 	 Image filename: img_000000572_Default_000.tif
# Index: 573 	 Image filename: img_000000573_Default_000.tif
# Index: 574 	 Image filename: img_000000574_Default_000.tif
# Index: 575 	 Image filename: img_000000575_Default_000.tif
# Index: 576 	 Image filename: img_000000576_Default_000.tif
# Index: 577 	 Image filename: img_000000577_Default_000.tif
# Index: 578 	 Image filename: img_000000578_Default_000.tif
# Index: 579 	 Image filename: img_000000579_Default_000.tif
# Index: 580 	 Image filename: img_000000580_Default_000.tif

# %% [markdown]
# ### Split ROI file into smaller files (allowing multi-processing of images)

# %%
num_of_files = 5
input_filename = Path('ROI_SU000001.json')
input_path = Path(
    '/Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1')

output_path = input_path
output_path.mkdir(parents=True, exist_ok=True)

with Path(input_path, input_filename).open('r') as f:
    data = json.load(f)

items = list(data.items())
total = len(items)
print(f'Number of ROIs: {total}')

base_size = total // num_of_files
remainder = total % num_of_files
split_sizes = [base_size + (1 if i < remainder else 0)
               for i in range(num_of_files)]

# Split the items into three chunks
chunks = []
start = 0
for size in split_sizes:
    end = start + size
    chunks.append(dict(items[start:end]))
    start = end

# Save each chunk to a separate JSON file
for i, chunk in enumerate(chunks, 1):
    output_file = Path(output_path, f'{input_filename.stem}_{i}.json')
    with output_file.open("w") as f:
        json.dump(chunk, f, indent=4)
    print(f"Saved {len(chunk)} dictionaries to {output_file}")
# Out:
# Number of ROIs: 145
# Saved 29 dictionaries to /Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/ROI_SU000001_1.json
# Saved 29 dictionaries to /Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/ROI_SU000001_2.json
# Saved 29 dictionaries to /Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/ROI_SU000001_3.json
# Saved 29 dictionaries to /Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/ROI_SU000001_4.json
# Saved 29 dictionaries to /Volumes/krauss/Lisa/GMR/Array/250206/Experiment_1_ethanol/loc1_1/ROI_SU000001_5.json
